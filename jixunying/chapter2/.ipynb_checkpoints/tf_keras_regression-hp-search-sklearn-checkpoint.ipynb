# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf

from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.0.0-alpha0
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# matplotlib 3.1.1
# numpy 1.16.2
# pandas 0.25.0
# sklearn 0.21.3
# tensorflow 2.0.0-alpha0
# tensorflow.python.keras.api._v2.keras 2.2.4-tf

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()
print(housing.DESCR)
print(housing.data.shape)
print(housing.target.shape)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. topic:: References
#
#     - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#       Statistics and Probability Letters, 33 (1997) 291-297
#
# (20640, 8)
# (20640,)

# %%
from sklearn.model_selection import train_test_split

x_train_all, x_test, y_train_all, y_test = train_test_split(
    housing.data, housing.target, random_state = 7)
x_train, x_valid, y_train, y_valid = train_test_split(
    x_train_all, y_train_all, random_state = 11)
print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape, y_test.shape)
# Out:
# (11610, 8) (11610,)
# (3870, 8) (3870,)
# (5160, 8) (5160,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaler = scaler.fit_transform(x_train)
x_valid_scaler = scaler.transform(x_valid)
x_test_scaler = scaler.transform(x_test)

# %%
#learning_rate: [1e-4, 3e-4, 1e-3, 3e-3, 1e-2, 3*e-2]

learning_rates = [1e-4, 3e-4, 1e-3, 3e-3, 1e-2, 3e-2]
histories = []
for lr in learning_rates:
    model = keras.models.Sequential([
        keras.layers.Dense(30, activation='relu',
                          input_shape=x_train.shape[1:]),
        keras.layers.Dense(1),
    ])
    opentimizer = keras.optimizers.SGD(lr)
    model.compile(loss="mean_squared_error",optimizer=opentimizer)
    callbacks = [keras.callbacks.EarlyStopping(
                 patience=5, min_delta=1e-2)]
    history = model.fit(x_train_scaler, y_train,
                    validation_data = (x_valid_scaler, y_valid),
                    epochs = 100,
                    callbacks = callbacks)
    histories.append(history)
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 0s 34us/sample - loss: 6.0933 - val_loss: 5.0861
# Epoch 2/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 4.1717 - val_loss: 3.6140
# Epoch 3/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 3.0229 - val_loss: 2.7107
# Epoch 4/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 2.3034 - val_loss: 2.1331
# Epoch 5/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 1.8383 - val_loss: 1.7546
# Epoch 6/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 1.5278 - val_loss: 1.4964
# Epoch 7/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 1.3129 - val_loss: 1.3144
# Epoch 8/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 1.1601 - val_loss: 1.1829
# Epoch 9/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 1.0485 - val_loss: 1.0849
# Epoch 10/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.9654 - val_loss: 1.0102
# Epoch 11/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.9024 - val_loss: 0.9528
# Epoch 12/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.8543 - val_loss: 0.9081
# Epoch 13/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.8171 - val_loss: 0.8731
# Epoch 14/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.7880 - val_loss: 0.8454
# Epoch 15/100
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.7652 - val_loss: 0.8232
# Epoch 16/100
# 11610/11610 [==============================] - 0s 26us/sample - loss: 0.7470 - val_loss: 0.8054
# Epoch 17/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.7325 - val_loss: 0.7909
# Epoch 18/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.7207 - val_loss: 0.7789
# Epoch 19/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.7109 - val_loss: 0.7690
# Epoch 20/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.7028 - val_loss: 0.7607
# Epoch 21/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6960 - val_loss: 0.7536
# Epoch 22/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.6901 - val_loss: 0.7474
# Epoch 23/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.6851 - val_loss: 0.7420
# Epoch 24/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6806 - val_loss: 0.7372
# Epoch 25/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6766 - val_loss: 0.7328
# Epoch 26/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6730 - val_loss: 0.7288
# Epoch 27/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6696 - val_loss: 0.7252
# Epoch 28/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6665 - val_loss: 0.7217
# Epoch 29/100
# 11610/11610 [==============================] - 0s 25us/sample - loss: 0.6636 - val_loss: 0.7184
# Epoch 30/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6608 - val_loss: 0.7153
# Epoch 31/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6581 - val_loss: 0.7124
# Epoch 32/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.6555 - val_loss: 0.7095
# Epoch 33/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6530 - val_loss: 0.7068
# Epoch 34/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.6506 - val_loss: 0.7041
# Epoch 35/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.6483 - val_loss: 0.7015
# Epoch 36/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6460 - val_loss: 0.6990
# Epoch 37/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.6437 - val_loss: 0.6966
# Epoch 38/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.6415 - val_loss: 0.6941
# Epoch 39/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.6394 - val_loss: 0.6918
# Epoch 40/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.6373 - val_loss: 0.6894
# Epoch 41/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.6352 - val_loss: 0.6871
# Epoch 42/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6331 - val_loss: 0.6849
# Epoch 43/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6311 - val_loss: 0.6827
# Epoch 44/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.6292 - val_loss: 0.6805
# Epoch 45/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.6272 - val_loss: 0.6784
# Epoch 46/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.6253 - val_loss: 0.6762
# Epoch 47/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6234 - val_loss: 0.6742
# Epoch 48/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6215 - val_loss: 0.6721
# Epoch 49/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.6196 - val_loss: 0.6701
# Epoch 50/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.6178 - val_loss: 0.6680
# Epoch 51/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.6160 - val_loss: 0.6661
# Epoch 52/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.6143 - val_loss: 0.6642
# Epoch 53/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.6125 - val_loss: 0.6622
# Epoch 54/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.6108 - val_loss: 0.6604
# Epoch 55/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.6091 - val_loss: 0.6585
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 0s 33us/sample - loss: 3.3993 - val_loss: 2.3921
# Epoch 2/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 1.8359 - val_loss: 1.4587
# Epoch 3/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 1.2106 - val_loss: 1.0820
# Epoch 4/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.9529 - val_loss: 0.9304
# Epoch 5/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.8394 - val_loss: 0.8628
# Epoch 6/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.7823 - val_loss: 0.8248
# Epoch 7/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.7482 - val_loss: 0.7988
# Epoch 8/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.7244 - val_loss: 0.7790
# Epoch 9/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.7061 - val_loss: 0.7618
# Epoch 10/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6907 - val_loss: 0.7465
# Epoch 11/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6773 - val_loss: 0.7329
# Epoch 12/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.6651 - val_loss: 0.7203
# Epoch 13/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6539 - val_loss: 0.7087
# Epoch 14/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6435 - val_loss: 0.6979
# Epoch 15/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6338 - val_loss: 0.6875
# Epoch 16/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6247 - val_loss: 0.6779
# Epoch 17/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.6161 - val_loss: 0.6688
# Epoch 18/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6080 - val_loss: 0.6602
# Epoch 19/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6004 - val_loss: 0.6520
# Epoch 20/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5932 - val_loss: 0.6443
# Epoch 21/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5862 - val_loss: 0.6368
# Epoch 22/100
# 11610/11610 [==============================] - 0s 25us/sample - loss: 0.5798 - val_loss: 0.6293
# Epoch 23/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5735 - val_loss: 0.6223
# Epoch 24/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5677 - val_loss: 0.6156
# Epoch 25/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5621 - val_loss: 0.6095
# Epoch 26/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5568 - val_loss: 0.6035
# Epoch 27/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5519 - val_loss: 0.5979
# Epoch 28/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5472 - val_loss: 0.5927
# Epoch 29/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5427 - val_loss: 0.5877
# Epoch 30/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5385 - val_loss: 0.5830
# Epoch 31/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5345 - val_loss: 0.5786
# Epoch 32/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.5307 - val_loss: 0.5741
# Epoch 33/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5271 - val_loss: 0.5702
# Epoch 34/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5236 - val_loss: 0.5664
# Epoch 35/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5203 - val_loss: 0.5623
# Epoch 36/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5172 - val_loss: 0.5586
# Epoch 37/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.5142 - val_loss: 0.5551
# Epoch 38/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.5113 - val_loss: 0.5519
# Epoch 39/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.5086 - val_loss: 0.5489
# Epoch 40/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.5060 - val_loss: 0.5460
# Epoch 41/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5035 - val_loss: 0.5429
# Epoch 42/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.5010 - val_loss: 0.5399
# Epoch 43/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.4988 - val_loss: 0.5373
# Epoch 44/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4965 - val_loss: 0.5347
# Epoch 45/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4944 - val_loss: 0.5323
# Epoch 46/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.4923 - val_loss: 0.5298
# Epoch 47/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4904 - val_loss: 0.5275
# Epoch 48/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4884 - val_loss: 0.5250
# Epoch 49/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4866 - val_loss: 0.5225
# Epoch 50/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4848 - val_loss: 0.5206
# Epoch 51/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4831 - val_loss: 0.5183
# Epoch 52/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4815 - val_loss: 0.5163
# Epoch 53/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.4799 - val_loss: 0.5143
# Epoch 54/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4784 - val_loss: 0.5123
# Epoch 55/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4769 - val_loss: 0.5106
# Epoch 56/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4755 - val_loss: 0.5089
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 0s 30us/sample - loss: 2.3284 - val_loss: 1.1453
# Epoch 2/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.9165 - val_loss: 0.8845
# Epoch 3/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.7794 - val_loss: 0.8136
# Epoch 4/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.7193 - val_loss: 0.7645
# Epoch 5/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.6759 - val_loss: 0.7241
# Epoch 6/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.6403 - val_loss: 0.6873
# Epoch 7/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.6110 - val_loss: 0.6589
# Epoch 8/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.5859 - val_loss: 0.6323
# Epoch 9/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.5650 - val_loss: 0.6114
# Epoch 10/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.5470 - val_loss: 0.5915
# Epoch 11/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.5313 - val_loss: 0.5745
# Epoch 12/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.5180 - val_loss: 0.5586
# Epoch 13/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.5060 - val_loss: 0.5477
# Epoch 14/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4964 - val_loss: 0.5349
# Epoch 15/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.4876 - val_loss: 0.5263
# Epoch 16/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4805 - val_loss: 0.5172
# Epoch 17/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.4737 - val_loss: 0.5097
# Epoch 18/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4678 - val_loss: 0.5027
# Epoch 19/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4626 - val_loss: 0.4962
# Epoch 20/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.4582 - val_loss: 0.4915
# Epoch 21/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: 0.4538 - val_loss: 0.4865
# Epoch 22/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4498 - val_loss: 0.4820
# Epoch 23/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4465 - val_loss: 0.4791
# Epoch 24/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4431 - val_loss: 0.4746
# Epoch 25/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4405 - val_loss: 0.4718
# Epoch 26/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4373 - val_loss: 0.4673
# Epoch 27/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4349 - val_loss: 0.4651
# Epoch 28/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4327 - val_loss: 0.4622
# Epoch 29/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4303 - val_loss: 0.4605
# Epoch 30/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4282 - val_loss: 0.4568
# Epoch 31/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4262 - val_loss: 0.4544
# Epoch 32/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4246 - val_loss: 0.4527
# Epoch 33/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4228 - val_loss: 0.4510
# Epoch 34/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4209 - val_loss: 0.4486
# Epoch 35/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4195 - val_loss: 0.4466
# Epoch 36/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4179 - val_loss: 0.4451
# Epoch 37/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4164 - val_loss: 0.4436
# Epoch 38/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4150 - val_loss: 0.4421
# Epoch 39/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4136 - val_loss: 0.4400
# Epoch 40/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.4123 - val_loss: 0.4383
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 0s 30us/sample - loss: 1.3176 - val_loss: 0.8880
# Epoch 2/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.7670 - val_loss: 0.7171
# Epoch 3/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.6194 - val_loss: 0.6345
# Epoch 4/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.5607 - val_loss: 0.5765
# Epoch 5/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.5208 - val_loss: 0.5492
# Epoch 6/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4985 - val_loss: 0.5120
# Epoch 7/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4767 - val_loss: 0.4991
# Epoch 8/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4568 - val_loss: 0.4804
# Epoch 9/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4534 - val_loss: 0.4754
# Epoch 10/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4681 - val_loss: 0.4655
# Epoch 11/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4423 - val_loss: 0.4555
# Epoch 12/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4336 - val_loss: 0.4532
# Epoch 13/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4265 - val_loss: 0.4428
# Epoch 14/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4267 - val_loss: 0.4663
# Epoch 15/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4239 - val_loss: 0.4328
# Epoch 16/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4186 - val_loss: 0.4328
# Epoch 17/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4114 - val_loss: 0.4343
# Epoch 18/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.4140 - val_loss: 0.4266
# Epoch 19/100
# 11610/11610 [==============================] - 0s 24us/sample - loss: 0.4035 - val_loss: 0.4185
# Epoch 20/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4010 - val_loss: 0.4175
# Epoch 21/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3995 - val_loss: 0.4162
# Epoch 22/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4007 - val_loss: 0.4116
# Epoch 23/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3936 - val_loss: 0.4118
# Epoch 24/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3911 - val_loss: 0.4065
# Epoch 25/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3932 - val_loss: 0.4108
# Epoch 26/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3962 - val_loss: 0.4045
# Epoch 27/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3906 - val_loss: 0.4000
# Epoch 28/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3884 - val_loss: 0.3978
# Epoch 29/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3830 - val_loss: 0.4017
# Epoch 30/100
# 11610/11610 [==============================] - ETA: 0s - loss: 0.390 - 0s 22us/sample - loss: 0.3908 - val_loss: 0.3989
# Epoch 31/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3810 - val_loss: 0.3930
# Epoch 32/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3831 - val_loss: 0.3911
# Epoch 33/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3822 - val_loss: 0.3897
# Epoch 34/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3765 - val_loss: 0.3909
# Epoch 35/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3748 - val_loss: 0.3859
# Epoch 36/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3772 - val_loss: 0.3852
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 0s 33us/sample - loss: 2.6967 - val_loss: 0.9927
# Epoch 2/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.4705 - val_loss: 0.4417
# Epoch 3/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.4046 - val_loss: 0.3994
# Epoch 4/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3810 - val_loss: 0.3909
# Epoch 5/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3734 - val_loss: 0.3722
# Epoch 6/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3675 - val_loss: 0.3688
# Epoch 7/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3628 - val_loss: 0.3665
# Epoch 8/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3605 - val_loss: 0.3612
# Epoch 9/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3574 - val_loss: 0.4601
# Epoch 10/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3563 - val_loss: 0.3627
# Epoch 11/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3520 - val_loss: 0.3629
# Epoch 12/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: 0.3504 - val_loss: 0.3574
# Epoch 13/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: 0.3494 - val_loss: 0.3680
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 0s 30us/sample - loss: nan - val_loss: nan
# Epoch 2/100
# 11610/11610 [==============================] - 0s 21us/sample - loss: nan - val_loss: nan
# Epoch 3/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: nan - val_loss: nan
# Epoch 4/100
# 11610/11610 [==============================] - 0s 22us/sample - loss: nan - val_loss: nan
# Epoch 5/100
# 11610/11610 [==============================] - 0s 23us/sample - loss: nan - val_loss: nan

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()
for lr, history in zip(learning_rates, histories):
    print("Learning rate: ", lr)
    plot_learning_curves(history)
# Out:
# Learning rate:  0.0001
# Learning rate:  0.0003
# Learning rate:  0.001
# Learning rate:  0.003
# Learning rate:  0.01
# Learning rate:  0.03
